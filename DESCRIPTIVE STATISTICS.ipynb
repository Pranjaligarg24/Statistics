# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sub_df = df [['sepal_length','sepal_width','petal_length','petal_width','species']]
sub_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# 1. Central Tendency
# Without directly calculating the mean, determine which sepal measurement (sepal_length or
# sepal_width) has a higher average by observing the dataset.

# %%
sub_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# 1. sepal_length has higher average because sepal_length has higher mean than the sepal_width.

# %% [markdown]
# 2. Dispersion
# Compare the variability of petal measurements by checking the difference between the
# ranges of petal_length and petal_width. Which feature shows more spread?

# %% [markdown]
# # Find the range of petal_length.

# %%
r1 = sub_df['petal_length'].max() - sub_df['petal_length'].min()
r1
# Out:
# 5.9

# %% [markdown]
# # Find the range of petal_width .

# %%
r2 = sub_df['petal_width'].max() - sub_df['petal_width'].min()
r2
# Out:
# 2.4

# %%
# 2. range of petal_length has more variability .

# %% [markdown]
# 3. Quartiles
# Identify which feature, sepal_length or sepal_width, has a higher interquartile range (IQR),
# indicating greater variability in the middle 50% of the data.

# %% [markdown]
# Find the IQR of sepal_length .

# %%
IQR1 = sub_df['sepal_length'].quantile(0.75) - sub_df['sepal_length'].quantile(0.25)
IQR1
# Out:
# 1.3000000000000007

# %% [markdown]
# Find the IQR of sepal_width.

# %%
IQR2= sub_df['sepal_width'].quantile(0.75) - sub_df['sepal_width'].quantile(0.25)
IQR2
# Out:
# 0.5

# %%
# 3. IQR 1 has the greater variability. so, sepal_length has more variability.

# %% [markdown]
# 4. Standard Deviation Insight
# Based on the computed standard deviations of sepal_length and sepal_width, determine
# which attribute exhibits more variability and discuss what this indicates about the
# consistency of the two features.

# %% [markdown]
# Find the standard deviation of sepal_length.

# %%
sd1 = sub_df["sepal_length"].std()
sd1
# Out:
# 0.8280661279778629

# %% [markdown]
# Find the standard deviation of sepal_width.

# %%
sd2 = sub_df["sepal_width"].std()
sd2
# Out:
# 0.4335943113621737

# %%
# 4. sepal_length has more standard deviation which means sepal_length data set has more variability but less consistency and sepal_width has less standard deviation which means sepal_width has less consistency.

# %% [markdown]
# 5. Shape of Distribution
# Without plotting, assess whether the petal_length distribution is skewed. Use a descriptive
# statistic that measures skewness and infer the distribution shape.

# %% [markdown]
# calculate mean , median and skew.

# %%
meanpetallength= sub_df['petal_length'].mean()
meanpetallength
# Out:
# 3.758666666666666

# %%
meadianpetallength= sub_df['petal_length'].median()
meadianpetallength
# Out:
# 4.35

# %%
skewpetallength = sub_df['petal_length'].skew()
skewpetallength
# Out:
# -0.27446425247378287

# %%
# 5. The data of petal_length is left skewed because mean of petal length is less than the median.

# %% [markdown]
# 6. Symmetry
# For which attribute, sepal_length or sepal_width, is the skewness closer to zero? What does
# this imply about the symmetry of its distribution?

# %% [markdown]
# calculate mean and median of sepal_length.

# %%
mean1=sub_df['sepal_length'].mean()
mean1
# Out:
# 5.843333333333334

# %%
median1=sub_df['sepal_length'].median()
median1
# Out:
# 5.8

# %%
skew = sub_df['sepal_length'].skew()
skew
# Out:
# 0.3149109566369728

# %% [markdown]
# calculate mean and median of sepal_width.

# %%
mean2=sub_df['sepal_width'].mean()
mean2
# Out:
# 3.0540000000000003

# %%
median2=sub_df['sepal_width'].median()
median2
# Out:
# 3.0

# %%
skew = sub_df['sepal_width'].skew()
skew
# Out:
# 0.3340526621720866

# %%
# 6. Both sepal_length and sepal_width are right skewed data and both attributes has not skewness which is closer to zero.

# %% [markdown]
# 7. Coefficient of Variation
# Calculate the coefficient of variation (CV) for sepal_length and petal_length. Which feature
# has greater relative variability, and what does this tell you about the dataset?

# %% [markdown]
# calculate CV of sepal_length.

# %%
cv1= sd1/mean1*100
cv1
# Out:
# 14.171125977944033

# %% [markdown]
# calculate CV of petal_length

# %%
meanpetallength= sub_df['petal_length'].mean()
meanpetallength
# Out:
# 3.758666666666666

# %%
cv2 = sd2/meanpetallength*100
cv2
# Out:
# 11.535854328543111

# %%
# 7. CV of sepal_length is greater so, sepal_length has greater variability and less consistency.

# %% [markdown]
# 8. Outlier Detection using IQR
# Identify the outliers in the sepal_length feature using the IQR method (define outliers as
# values that fall below Q1 - 1.5 * IQR or above Q3 + 1.5 * IQR). How many outliers are
# present?

# %% [markdown]
# Find the outliers of sepal_length.

# %%
lowerbound = sub_df['sepal_length'].quantile(0.25) - 1.5 * IQR1

lowerbound
# Out:
# 3.1499999999999986

# %%
upperbound = sub_df['sepal_length'].quantile(0.75) + 1.5 * IQR1

upperbound
# Out:
# 8.350000000000001

# %%
outliers = sub_df[(sub_df['sepal_length'] < lowerbound) | (sub_df['sepal_length'] > upperbound)]
print("Outliers Rows:")
print(outliers)
# Out:
# Outliers Rows:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
#8.there is no outliers.
